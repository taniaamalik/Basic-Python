# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("1")
print("12")
print("1 3")
print("1  4")
print("12345")
# Out:
# 1
# 12
# 1 3
# 1  4
# 12345

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("1","12","1 3","1  4","12345", sep="\n")
# Out:
# 1
# 12
# 1 3
# 1  4
# 12345

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x="FGA"
N=10
print(x*N)
# Out:
# FGAFGAFGAFGAFGAFGAFGAFGAFGAFGA

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("FGA", end=" ")
print("BIG DATA", end=" ")
print("2021")
# Out:
# FGA BIG DATA 2021

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
hg1 = 100
hg2 = 200
hg3 = 300
hg4 = 150
hg5 = 400

b1 = 10
b2 = 8
b3 = 9
b4 = 15
b5 = 20

total_penjualan = (hg1 * b1) + (hg2 * b2) + (hg3 * b3) + (hg4 * b4) + (hg5 * b5)
print("Total uang yang diperoleh : ", total_penjualan)
# Out:
# Total uang yang diperoleh :  15550

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
jam_awal  = int(input("Jam awal : "))
menit_awal = int(input("Menit awal : "))
jam_akhir  = int(input("Jam akhir : "))
menit_akhir = int(input("Menit akhir : "))

total_jam = jam_akhir - jam_awal
jam_ke_menit = total_jam * 60
total_menit = menit_akhir - menit_awal
lama_perjalanan = jam_ke_menit + total_menit

print("Lama perjalanan :", lama_perjalanan, "menit")
# Out:
# Jam awal : 8
# Menit awal : 20
# Jam akhir : 10
# Menit akhir : 10
# Lama perjalanan : 110 menit

# %%
# or
jamawal =8
menitawal=20
jamakhir =10
menitakhir=10

waktu=(jamakhir*60-jamawal*60-menitawal+menitakhir)
print("Waktu yang diperlukan=",waktu,"menit")
# Out:
# Waktu yang diperlukan= 110 menit

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
jam_awal  = int(input("Jam awal : "))
menit_awal = int(input("Menit awal : "))
jam_akhir  = int(input("Jam akhir : "))
menit_akhir = int(input("Menit akhir : "))

total_jam = jam_akhir - jam_awal
jam_ke_menit = total_jam * 60
total_menit = menit_akhir - menit_awal + jam_ke_menit

biaya_permenit = 2

biaya_perjalanan = total_menit * biaya_permenit

print("Biaya perjalanan : ", biaya_perjalanan, "$", sep = "")
# Out:
# Jam awal : 8
# Menit awal : 20
# Jam akhir : 10
# Menit akhir : 10
# Biaya perjalanan : 220$

# %%
# or
jamawal =8
menitawal=20
jamakhir =10
menitakhir=10
waktu=(jamakhir*60-jamawal*60-menitawal+menitakhir)
biaya=waktu*2
print("Biaya perjalanan yang diperlukan=",biaya,"$")
# Out:
# Biaya perjalanan yang diperlukan= 220 $

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = int(input("Nilai x : "))
y = int(input("Nilai y : "))
z = int(input("Nilai z : "))
a = (x**3 + z) / y ** z + 5
print(a)
# Out:
# Nilai x : 1
# Nilai y : 2
# Nilai z : 3
# 5.5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = int(input("Nilai x : "))
y = 2 + x / (2 + x / (2 + x / (2 + x / (2 + x / 2))))
print(y)
# Out:
# Nilai x : 1
# 2.414285714285714

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = int(input("Nilai a : "))
b = int(input("Nilai b : "))
c = int(input("Nilai c : "))
d = int(input("Nilai d : "))
e = int(input("Nilai e : "))
rata_rata = (a + b + c + d + e) / 5
print("Nilai rata-rata :", rata_rata)
# Out:
# Nilai a : 5
# Nilai b : 4
# Nilai c : 3
# Nilai d : 2
# Nilai e : 1
# Nilai rata-rata : 3.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
jam_awal  = int(input("Jam awal : "))
menit_awal = int(input("Menit awal : "))
jam_akhir  = int(input("Jam akhir : "))
menit_akhir = int(input("Menit akhir : "))

total_jam = jam_akhir - jam_awal
jam_ke_menit = total_jam * 60
total_menit = menit_akhir - menit_awal + jam_ke_menit

jam_perjalanan = total_menit // 60
menit_perjalanan = total_menit % 60

print("Lama perjalanan adalah", jam_perjalanan, "jam", menit_perjalanan, "menit")
# Out:
# Jam awal : 8
# Menit awal : 20
# Jam akhir : 10
# Menit akhir : 10
# Lama perjalanan adalah 1 jam 50 menit

# %%
# or
jamawal =8
menitawal=20
jamakhir =10
menitakhir=10
jam=(jamakhir*60-jamawal*60-menitawal+menitakhir)//60
menit=(jamakhir*60-jamawal*60-menitawal+menitakhir)%60
print("Jam =",jam,"Menit =",menit)
# Out:
# Jam = 1 Menit = 50

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
jam_awal  = int(input("Jam awal : "))
menit_awal = int(input("Menit awal : "))
jam_akhir  = int(input("Jam akhir : "))
menit_akhir = int(input("Menit akhir : "))

total_jam = jam_akhir - jam_awal
jam_ke_menit = total_jam * 60
total_menit = menit_akhir - menit_awal + jam_ke_menit

jam_perjalanan = total_menit // 60
menit_perjalanan = total_menit % 60

biaya_perjam = 20
biaya_permenit = 2

total_biaya = (jam_perjalanan * biaya_perjam) + (menit_perjalanan * biaya_permenit)

print("Biaya perjalanan : ", total_biaya, "$", sep = "")
# Out:
# Jam awal : 8
# Menit awal : 20
# Jam akhir : 10
# Menit akhir : 10
# Biaya perjalanan : 120$

# %%
# or
jamawal =8
menitawal=20
jamakhir =10
menitakhir=10
jam=(jamakhir*60-jamawal*60-menitawal+menitakhir)//60
menit=(jamakhir*60-jamawal*60-menitawal+menitakhir)%60
print("Jam=", jam," Menit=",menit)
biaya=jam*20+2*menit
print("Biaya perjalanan yang diperlukan=",biaya,"$")
# Out:
# Jam= 1  Menit= 50
# Biaya perjalanan yang diperlukan= 120 $

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
30
jam_awal  = int(input("Jam awal : "))
menit_awal = int(input("Menit awal : "))
detik_awal = int(input("Detik awal : "))
jam_akhir  = int(input("Jam akhir : "))
menit_akhir = int(input("Menit akhir : "))
detik_akhir = int(input("Detik akhir : "))
# 1:50:15 6615 detik
total_jam = jam_akhir - jam_awal
jam_ke_detik = total_jam * 3600
total_menit = menit_akhir - menit_awal
menit_ke_detik = total_menit * 60
total_detik = detik_akhir - detik_awal + jam_ke_detik + menit_ke_detik

jam_perjalanan = total_detik // 3600
menit_perjalanan = (total_detik % 3600) // 60
detik_perjalanan = (total_detik % 3600) % 60
# ATAU
# jam_perjalanan = total_detik // 3600
# menit_perjalanan = (total_detik - (jam_perjalanan * 3600)) // 60
# detik_perjalanan = (total_detik1 - (jam_perjalanan * 3600)) % 60

biaya_perjam = 20
biaya_permenit = 2
biaya_perdetik = 1

total_biaya = (jam_perjalanan * biaya_perjam) + (menit_perjalanan * biaya_permenit) + (detik_perjalanan * biaya_perdetik)

print("Biaya perjalanan : ", total_biaya, "$", sep = "")
# Out:
# Jam awal : 8
# Menit awal : 20
# Detik awal : 15
# Jam akhir : 10
# Menit akhir : 10
# Detik akhir : 30
# Biaya perjalanan : 135$

# %%
# or
jamawal =8
menitawal=20
detikawal=15
jamakhir =10
menitakhir=10
detikahir=30
jam=(jamakhir*60*60-jamawal*60*60-menitawal*60+menitakhir*60-detikawal+detikahir)//(60*60)
menit=((jamakhir*60*60-jamawal*60*60-menitawal*60+menitakhir*60-detikawal+detikahir)-jam*60*60)//60
detik=((jamakhir*60*60-jamawal*60*60-menitawal*60+menitakhir*60-detikawal+detikahir)-jam*60*60-menit*60)
print("Jam =", jam," Menit",menit,"detik =",detik)
biaya=jam*20+2*menit+detik
print("Biaya perjalanan yang diperlukan=",biaya,"$")
# Out:
# Jam = 1  Menit 50 detik = 15
# Biaya perjalanan yang diperlukan= 135 $
